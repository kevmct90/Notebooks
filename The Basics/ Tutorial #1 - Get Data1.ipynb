# %% [markdown]
# # Tutorial #1: Get Data
#
# This tutorial covers:
#
# 1. An introduction to Notebooks
# 1. A quick tour of IBM Data Scientist Workbench
# 1. Uploading files to the workbench
# 1. Renaming files in the workbench
# 1. Importing files from external URLs
# 1. Loading a CSV file into a `pandas` DataFrame
# 1. Manipulating a DataFrame

# %% [markdown]
# ## Import a File
# You can also import a publicly addressable file into your workbench data folder by entering its URL into the search box in the top navigation bar.  The file at the URL will automatically download into your workbench data folder as long as it is:
#
# 1. accessible via HTTP or HTTPS protocol, and
# 1. one of the following media types:
#     * Plain text
#     * CSV
#     * JSON (including `*.ipynb` notebooks)

# %% [markdown]
# ## Load Data
# **[pandas](http://pandas-docs.github.io/pandas-docs-travis/)** is a Python package that provides data structures for managing structured data.  The two primary data structures of pandas are the [Series](http://pandas-docs.github.io/pandas-docs-travis/dsintro.html#series) (1-dimensional) and [DataFrame](http://pandas-docs.github.io/pandas-docs-travis/dsintro.html#dataframe) (2-dimensional).
#
# In the following steps, we'll load the olympic medals by country CSV file into a DataFrame in memory.

# %% [markdown]
# ### Step 1: Import the `pandas` Package into our notebook.
# Click on the code cell below, then click the right arrow button (**&#9658;**) in the notebook toolbar to run the code.

# %%
import pandas

# %% [markdown]
# ### Step 2: Create a new code cell
# Click on the plus button (**+**) in the Notebook toolbar to create a new cell.
#
# Click the newly created cell and enter the following line of code:
# <pre>medals_df = pandas.read_csv('')</pre>

# %%
medals_df = pandas.read_csv('medals.csv')

# %% [markdown]
# ## Manipulate a DataFrame
# Now that we have the data in memory, we can explore and manipulate it.
#
# Print the first and last 5 rows of the data using the `head()` and `tail()` methods.  Run each code cell below.

# %%
medals_df.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
medals_df.tail()
# Out:
#           Year                     City   Sport Discipline  NOC  \
# 2309      2006                    Turin  Skiing  Snowboard  USA
# 2310      2006                    Turin  Skiing  Snowboard  USA
# 2311       NaN                      NaN     NaN        NaN  NaN
# 2312    SOURCE                      IOC     NaN        NaN  NaN
# 2313  DATALINK  http://www.olympic.org/     NaN        NaN  NaN
#
#                 Event Event gender   Medal
# 2309  Snowboard Cross            M    Gold
# 2310  Snowboard Cross            W  Silver
# 2311              NaN          NaN     NaN
# 2312              NaN          NaN     NaN
# 2313              NaN          NaN     NaN

# %% [markdown]
# The tail output shows us that the CSV file contains lines at the bottom that are not data.  The cell values at these rows and columns is `NaN` (not a number).
#
# We can prune these rows from our data by running the following code cell.

# %%
medals_df = medals_df.dropna()
medals_df.tail()
# Out:
#       Year   City   Sport Discipline  NOC            Event Event gender  \
# 2306  2006  Turin  Skiing  Snowboard  USA        Half-pipe            M
# 2304  2006                   Turin      Skiing       Snowboard  USA
# 2306  2006                   Turin      Skiing       Snowboard  USA
# 2308  2006                   Turin      Skiing       Snowboard  USA
# 2305  2006                   Turin      Skiing       Snowboard  USA
# 2307  2006                   Turin      Skiing       Snowboard  USA
# 2310  2006                   Turin      Skiing       Snowboard  USA
# 2309  2006                   Turin      Skiing       Snowboard  USA
# 2287  2006                   Turin     Curling         Curling  USA
# 2302  2006                   Turin      Skiing   Alpine Skiing  USA
# 2289  2006                   Turin     Skating  Figure skating  USA
# 2288  2006                   Turin  Ice Hockey      Ice Hockey  USA
# 2290  2006                   Turin     Skating  Figure skating  USA
# 2303  2006                   Turin      Skiing  Freestyle Ski.  USA
# 2286  2006                   Turin   Bobsleigh       Bobsleigh  USA
# 1619  1994             Lillehammer      Skiing  Freestyle Ski.  UZB
# 1127  1984                Sarajevo      Skiing   Alpine Skiing  YUG
# 1264  1988                 Calgary      Skiing     Ski Jumping  YUG
# 1265  1988                 Calgary      Skiing     Ski Jumping  YUG
# 1263  1988                 Calgary      Skiing   Alpine Skiing  YUG
#
#                       Event Event gender   Medal
# 1437            5000m relay            M  Bronze
# 1620                 slalom            W  Bronze
# 1825                  1000m            M    Gold
# 1826                aerials            W    Gold
# 2059                aerials            W  Bronze
# 2060                 moguls            M    Gold
# 0                individual            M  Silver
# 1                individual            W    Gold
# 2                     pairs            X    Gold
# 49               individual            M  Silver
# 50               individual            W  Silver
# 52                    pairs            X  Silver
# 51                    pairs            X  Bronze
# 91               individual            W  Silver
# 90               individual            M    Gold
# 135                  10000m            M  Bronze
# 133              individual            M    Gold
# 132              individual            M  Bronze
# 134                   pairs            X  Silver
# 186         alpine combined            W    Gold
# 185         alpine combined            W  Bronze
# 187                downhill            M  Silver
# 189                downhill            W  Silver
# 188                downhill            W  Bronze
# 184              individual            W  Silver
# 183              individual            M  Bronze
# 190                  slalom            W  Bronze
# 253                downhill            M  Silver
# 254                downhill            W    Gold
# 252                downhill            M  Bronze
# ...                     ...          ...     ...
# 2294                 10000m            M  Silver
# 2296                  1000m            M  Silver
# 2295                  1000m            M    Gold
# 2291                  1000m            M  Bronze
# 2298                  1500m            M  Silver
# 2297                  1500m            M  Bronze
# 2299                  5000m            M    Gold
# 2292            5000m relay            M  Bronze
# 2293                   500m            M    Gold
# 2300                   500m            M    Gold
# 2301        Alpine combined            M    Gold
# 2304  Giant parallel slalom            W  Bronze
# 2306              Half-pipe            M  Silver
# 2308              Half-pipe            W  Silver
# 2305              Half-pipe            M    Gold
# 2307              Half-pipe            W    Gold
# 2310        Snowboard Cross            W  Silver
# 2309        Snowboard Cross            M    Gold
# 2287                curling            M  Bronze
# 2302           giant slalom            W    Gold
# 2289            ice dancing            X  Silver
# 2288             ice hockey            W  Bronze
# 2290             individual            W  Silver
# 2303                 moguls            M  Bronze
# 2286                two-man            W  Silver
# 1619                aerials            W    Gold
# 1127           giant slalom            M  Silver
# 1264  K120 individual (90m)            M  Bronze
# 1265        K120 team (90m)            M  Silver
# 1263                 slalom            W  Silver
#
# [2311 rows x 8 columns]
